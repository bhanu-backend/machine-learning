# %% [raw]
# Classification (Hyper Plane) Gamma(low Gamma ->near , High Gamma ->far away also) and Regularization
# High Regularization(Overfitting) Low Regularization(efficient) (C) kernel

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
df = load_iris()
dir(df)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']
